# %%
import matplotlib
# %matplotlib inline

import pylab 

n = 100 # size of space: n x n
p = 0.1 # probability of initially panicky individuals
def initialize():
    global config, nextconfig, density
    density = []
    config = pylab.zeros([n, n])
    for x in range(n):
        for y in range(n):
            config[x, y] = 1 if pylab.random() < p else 0
    nextconfig = zeros([n, n])
    
    
def observe():
    global config, nextconfig
    pylab.cla()
    pylab.imshow(config, vmin = 0, vmax = 1, cmap = cm.binary)
    
    
def update():
    global config, nextconfig, density
    
    d = 0
    
    
    for x in range(n):
        for y in range(n):
            count = 0
            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    count += config[(x + dx) % n, (y + dy) % n]
            
            
            if config[x, y] == 1:
                d += 1
                if count ==3 or count == 2:
                    nextconfig[x, y] = 1
                else:
                    nextconfig[x, y] = 0
            else:
                if count ==3:
                    nextconfig[x, y] = 1
                else:
                    nextconfig[x, y] = 0
                    
    density.append(d/(n*n))
                    
            
    config, nextconfig = nextconfig, config

# %%
initialize()
for i in range(10):
    update()
    observe()

# %%
print(density)
plt.plot(density)
# Out:
# [0.1007, 0.0811, 0.0664, 0.0619, 0.0574, 0.0536, 0.0529, 0.044, 0.04, 0.0379]

# %%
initialize(0.2)
for i in range(10):
    update()
    observe()

# %%
import matplotlib
# %matplotlib inline

import pylab 

n = 100 # size of space: n x n
# probability of initially panicky individuals
def initialize(p):
    global config, nextconfig, density
    density = []
    config = pylab.zeros([n, n])
    for x in range(n):
        for y in range(n):
            config[x, y] = 1 if pylab.random() < p else 0
    nextconfig = zeros([n, n])
    
    
def observe():
    global config, nextconfig
    pylab.cla()
    pylab.imshow(config, vmin = 0, vmax = 1, cmap = cm.binary)
    
    
def update():
    global config, nextconfig, density
    
    d = 0
    
    
    for x in range(n):
        for y in range(n):
            count = 0
            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    count += config[(x + dx) % n, (y + dy) % n]
            
            
            nextconfig[x, y] = 1 if count >= 4 else 0
                    
    density.append(d/(n**2))
                    
            
    config, nextconfig = nextconfig, config

# %%
initialize(0.1)
for i in range(30):
    update()
    observe()

# %%
initialize(0.25)
for i in range(30):
    update()
    observe()

# %%
initialize(0.3)
for i in range(30):
    update()
    observe()

# %%
initialize(0.35)
for i in range(30):
    update()
    observe()

# %%
#Around which value of the initial density parameter does the phase transition (the
#whole space getting filled with panic) happen?


#We can see that hte phase transition happens at round 0.35
